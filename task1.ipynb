# %%
import pandas as pd

# %%
_df=pd.read_csv("TASK1.csv")

# %%
type(_df)
# Out:
# pandas.core.frame.DataFrame

# %%
_df
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 0               1   NaN    Male         Blouse     Clothing
# 1               2   NaN    Male        Sweater     Clothing
# 2               3   NaN    Male          Jeans     Clothing
# 3               4   NaN    Male        Sandals     Footwear
# 4               5   NaN    Male         Blouse     Clothing
# ...           ...   ...     ...            ...          ...
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                       NaN       Kentucky    L       Gray  Winter
# 1                       NaN          Maine    L     Maroon  Winter
# ...

# %%
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3269 non-null   float64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
_df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3269.000000            3285.000000    3246.000000
# mean   1950.500000    43.973998              59.863014       3.744239
# std    1125.977353    15.216359              23.673623       0.719448
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.750000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
_df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
_df.shape
# Out:
# (3900, 19)

# %%
_df.columns = [c.replace(' ', '_') for c in _df.columns]

# %%
_df.Previous_Purchases
# Out:
# 0       14
# 1        2
# 2       23
# 3       49
# 4       31
#         ..
# 3895    32
# 3896    41
# 3897    24
# 3898    24
# 3899    33
# Name: Previous_Purchases, Length: 3900, dtype: int64

# %%
_df.at[345,'Previous_Purchases']
# Out:
# 27

# %%
_df.head(10)
# Out:
#    Customer_ID   Age Gender Item_Purchased     Category  \
# 0            1   NaN   Male         Blouse     Clothing
# 1            2   NaN   Male        Sweater     Clothing
# 2            3   NaN   Male          Jeans     Clothing
# 3            4   NaN   Male        Sandals     Footwear
# 4            5   NaN   Male         Blouse     Clothing
# 5            6   NaN   Male       Sneakers     Footwear
# 6            7   NaN   Male          Shirt     Clothing
# 7            8   NaN   Male         Shorts     Clothing
# 8            9   NaN   Male           Coat    Outerwear
# 9           10  57.0   Male        Handbag  Accessories
#
#    Purchase_Amount_(USD)       Location Size      Color  Season  \
# 0                    NaN       Kentucky    L       Gray  Winter
# 1                    NaN          Maine    L     Maroon  Winter
# 2                    NaN  Massachusetts    S     Maroon  Spring
# 3                   90.0   Rhode Island    M     Maroon  Spring
# ...

# %%
_df.tail(10)
# Out:
#       Customer_ID   Age  Gender Item_Purchased     Category  \
# 3890         3891  35.0  Female          Shirt     Clothing
# 3891         3892  36.0  Female          Dress     Clothing
# 3892         3893  35.0  Female        Jewelry  Accessories
# 3893         3894   NaN  Female            Hat  Accessories
# 3894         3895  66.0  Female          Skirt     Clothing
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase_Amount_(USD)       Location Size      Color  Season  \
# 3890                   81.0       Nebraska   XL      Green  Winter
# 3891                   30.0       Colorado    L      Peach  Winter
# 3892                   86.0       Michigan    L     Indigo  Summer
# ...

# %%
_df.loc()

# %%
_df.isnull().sum()
# Out:
# Customer_ID                   0
# Age                         631
# Gender                        0
# Item_Purchased                0
# Category                      0
# Purchase_Amount_(USD)       615
# Location                      0
# Size                          0
# Color                         0
# Season                        0
# Review_Rating               654
# Subscription_Status           0
# Payment_Method                0
# Shipping_Type                 0
# Discount_Applied              0
# Promo_Code_Used               0
# Previous_Purchases            0
# Preferred_Payment_Method      0
# Frequency_of_Purchases        0
# dtype: int64

# %%
_df.Age.plot();
